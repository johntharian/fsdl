# %%
# !pip install torch pytorch-lightning torchvision matplotlib  scikit-learn
# Out:
# Requirement already satisfied: torch in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (2.0.1)
# Requirement already satisfied: pytorch-lightning in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (2.0.7)
# Requirement already satisfied: torchvision in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (0.15.2)
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (3.7.2)
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/77/85/bff3a1e818ec6aa3dd466ff4f4b0a727db9fdb41f2e849747ad902ddbe95/scikit_learn-1.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.3.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: filelock in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy>=1.17.2 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (1.25.2)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (1.0.3)
# Requirement already satisfied: packaging>=17.1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (23.0)
# Requirement already satisfied: lightning-utilities>=0.7.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from pytorch-lightning) (0.9.0)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from torchvision) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from matplotlib) (2.8.2)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.5.0 from https://files.pythonhosted.org/packages/06/15/e73734f9170b66c6a84a0bd7e03586e87e77404e2eb8e34749fc49fa43f7/scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.1 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.1 kB ? eta -:--:--
#      ---------------------------------------- 59.1/59.1 kB 1.0 MB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from tqdm>=4.57.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\envs\pytorch_env\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Downloading scikit_learn-1.3.0-cp311-cp311-win_amd64.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.2 MB 2.0 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.2 MB 2.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/9.2 MB 2.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/9.2 MB 2.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/9.2 MB 2.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/9.2 MB 2.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.7/9.2 MB 2.3 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.2 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.2 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/9.2 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.2/9.2 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.4/9.2 MB 2.6 MB/s eta 0:00:04
#    ------ --------------------------------- 1.5/9.2 MB 2.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.2 MB 2.6 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.2 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.9/9.2 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 2.0/9.2 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.2 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.3/9.2 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/9.2 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.5/9.2 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 2.8/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 2.9/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.0/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.2 MB 2.6 MB/s eta 0:00:03
#    --------------- ------------------------ 3.5/9.2 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.2 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.7/9.2 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.2 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.0/9.2 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/9.2 MB 2.6 MB/s eta 0:00:02
#    ------------------ --------------------- 4.3/9.2 MB 2.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.4/9.2 MB 2.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.5/9.2 MB 2.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.2 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 4.8/9.2 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.2 MB 2.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.1/9.2 MB 2.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.3/9.2 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.4/9.2 MB 2.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.2 MB 2.6 MB/s eta 0:00:02
#    ------------------------ --------------- 5.6/9.2 MB 2.6 MB/s eta 0:00:02
#    ------------------------ --------------- 5.7/9.2 MB 2.6 MB/s eta 0:00:02
#    ------------------------- -------------- 5.9/9.2 MB 2.7 MB/s eta 0:00:02
#    -------------------------- ------------- 6.0/9.2 MB 2.6 MB/s eta 0:00:02
#    -------------------------- ------------- 6.1/9.2 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 6.3/9.2 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 6.4/9.2 MB 2.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.5/9.2 MB 2.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.6/9.2 MB 2.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.9/9.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.1/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.2/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.2 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.5/9.2 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 7.6/9.2 MB 2.6 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.9/9.2 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.0/9.2 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.1/9.2 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.2/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.4/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.2 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 8.6/9.2 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 8.8/9.2 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  9.0/9.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.2 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 2.6 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    --------- ------------------------------ 71.7/302.2 kB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/302.2 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 302.2/302.2 kB 2.7 MB/s eta 0:00:00
# Downloading scipy-1.11.2-cp311-cp311-win_amd64.whl (44.0 MB)
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/44.0 MB 1.7 MB/s eta 0:00:27
#    ---------------------------------------- 0.2/44.0 MB 2.1 MB/s eta 0:00:21
#    ---------------------------------------- 0.3/44.0 MB 2.5 MB/s eta 0:00:18
#    ---------------------------------------- 0.5/44.0 MB 2.6 MB/s eta 0:00:17
#     --------------------------------------- 0.6/44.0 MB 2.6 MB/s eta 0:00:17
#     --------------------------------------- 0.8/44.0 MB 2.8 MB/s eta 0:00:16
#     --------------------------------------- 0.9/44.0 MB 2.8 MB/s eta 0:00:16
#     --------------------------------------- 1.0/44.0 MB 2.9 MB/s eta 0:00:16
#    - -------------------------------------- 1.2/44.0 MB 2.7 MB/s eta 0:00:16
#    - -------------------------------------- 1.3/44.0 MB 2.8 MB/s eta 0:00:16
#    - -------------------------------------- 1.4/44.0 MB 2.8 MB/s eta 0:00:16
#    - -------------------------------------- 1.5/44.0 MB 2.7 MB/s eta 0:00:16
#    - -------------------------------------- 1.7/44.0 MB 2.7 MB/s eta 0:00:16
#    - -------------------------------------- 1.8/44.0 MB 2.7 MB/s eta 0:00:16
#    - -------------------------------------- 1.9/44.0 MB 2.8 MB/s eta 0:00:15
#    - -------------------------------------- 2.0/44.0 MB 2.7 MB/s eta 0:00:16
#    - -------------------------------------- 2.1/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 2.3/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 2.4/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 2.6/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 2.7/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 2.8/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 2.9/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 3.0/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 3.1/44.0 MB 2.7 MB/s eta 0:00:16
#    -- ------------------------------------- 3.2/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 3.3/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 3.5/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 3.6/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 3.6/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 3.7/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 3.9/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 4.0/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 4.2/44.0 MB 2.6 MB/s eta 0:00:16
#    --- ------------------------------------ 4.3/44.0 MB 2.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.4/44.0 MB 2.6 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.5/44.0 MB 2.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.7/44.0 MB 2.6 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.8/44.0 MB 2.6 MB/s eta 0:00:15
#    ---- ----------------------------------- 4.9/44.0 MB 2.6 MB/s eta 0:00:15
#    ---- ----------------------------------- 5.0/44.0 MB 2.6 MB/s eta 0:00:15
#    ---- ----------------------------------- 5.2/44.0 MB 2.7 MB/s eta 0:00:15
#    ---- ----------------------------------- 5.3/44.0 MB 2.6 MB/s eta 0:00:15
#    ---- ----------------------------------- 5.5/44.0 MB 2.6 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.6/44.0 MB 2.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.7/44.0 MB 2.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.9/44.0 MB 2.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.0/44.0 MB 2.7 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.1/44.0 MB 2.6 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.2/44.0 MB 2.6 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.3/44.0 MB 2.6 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.4/44.0 MB 2.6 MB/s eta 0:00:15
#    ----- ---------------------------------- 6.5/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 6.6/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 6.7/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 6.8/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 6.9/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 7.1/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 7.2/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 7.3/44.0 MB 2.6 MB/s eta 0:00:15
#    ------ --------------------------------- 7.5/44.0 MB 2.6 MB/s eta 0:00:14
#    ------ --------------------------------- 7.6/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 7.7/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 7.8/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.0/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.1/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.2/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.3/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.4/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.6/44.0 MB 2.6 MB/s eta 0:00:14
#    ------- -------------------------------- 8.6/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 8.8/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 8.9/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.0/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.1/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.2/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.4/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.5/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.6/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.7/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.8/44.0 MB 2.6 MB/s eta 0:00:14
#    -------- ------------------------------- 9.9/44.0 MB 2.6 MB/s eta 0:00:14
#    --------- ------------------------------ 10.0/44.0 MB 2.6 MB/s eta 0:00:14
#    --------- ------------------------------ 10.1/44.0 MB 2.6 MB/s eta 0:00:14
#    --------- ------------------------------ 10.2/44.0 MB 2.6 MB/s eta 0:00:14
#    --------- ------------------------------ 10.3/44.0 MB 2.6 MB/s eta 0:00:13
#    --------- ------------------------------ 10.5/44.0 MB 2.6 MB/s eta 0:00:13
#    --------- ------------------------------ 10.6/44.0 MB 2.6 MB/s eta 0:00:13
#    --------- ------------------------------ 10.7/44.0 MB 2.6 MB/s eta 0:00:13
#    --------- ------------------------------ 10.8/44.0 MB 2.6 MB/s eta 0:00:13
#    --------- ------------------------------ 10.9/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.1/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.2/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.3/44.0 MB 2.5 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.4/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.6/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.7/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 11.8/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 12.0/44.0 MB 2.6 MB/s eta 0:00:13
#    ---------- ----------------------------- 12.1/44.0 MB 2.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 12.2/44.0 MB 2.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 12.4/44.0 MB 2.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 12.5/44.0 MB 2.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 12.6/44.0 MB 2.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 12.8/44.0 MB 2.6 MB/s eta 0:00:13
#    ----------- ---------------------------- 12.9/44.0 MB 2.6 MB/s eta 0:00:12
#    ----------- ---------------------------- 13.0/44.0 MB 2.6 MB/s eta 0:00:12
#    ----------- ---------------------------- 13.2/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 13.3/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 13.4/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 13.5/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 13.6/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 13.7/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 13.9/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 14.0/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------ --------------------------- 14.2/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 14.3/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 14.4/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 14.6/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 14.7/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 14.8/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 14.9/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 15.0/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 15.2/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 15.2/44.0 MB 2.6 MB/s eta 0:00:12
#    ------------- -------------------------- 15.4/44.0 MB 2.6 MB/s eta 0:00:12
#    -------------- ------------------------- 15.5/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 15.6/44.0 MB 2.6 MB/s eta 0:00:12
#    -------------- ------------------------- 15.7/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 15.8/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 15.9/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 16.1/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 16.2/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 16.2/44.0 MB 2.6 MB/s eta 0:00:11
#    -------------- ------------------------- 16.4/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 16.6/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 16.7/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 16.8/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 16.9/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 17.0/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 17.2/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 17.3/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 17.4/44.0 MB 2.6 MB/s eta 0:00:11
#    --------------- ------------------------ 17.6/44.0 MB 2.6 MB/s eta 0:00:11
#    ---------------- ----------------------- 17.7/44.0 MB 2.6 MB/s eta 0:00:11
#    ---------------- ----------------------- 17.8/44.0 MB 2.6 MB/s eta 0:00:11
#    ---------------- ----------------------- 18.0/44.0 MB 2.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 18.1/44.0 MB 2.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 18.3/44.0 MB 2.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 18.4/44.0 MB 2.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 18.5/44.0 MB 2.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 18.7/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 18.8/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 18.9/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.0/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.1/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.3/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.4/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.5/44.0 MB 2.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.5/44.0 MB 2.6 MB/s eta 0:00:10
#    ----------------- ---------------------- 19.7/44.0 MB 2.6 MB/s eta 0:00:10
#    ------------------ --------------------- 19.8/44.0 MB 2.7 MB/s eta 0:00:10
#    ------------------ --------------------- 20.0/44.0 MB 2.7 MB/s eta 0:00:10
#    ------------------ --------------------- 20.1/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------ --------------------- 20.2/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------ --------------------- 20.3/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------ --------------------- 20.4/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------ --------------------- 20.6/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------ --------------------- 20.7/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------ --------------------- 20.8/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 20.9/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.0/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.1/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.2/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.4/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.5/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.6/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.7/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 21.9/44.0 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 22.0/44.0 MB 2.7 MB/s eta 0:00:09
#    -------------------- ------------------- 22.1/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 22.2/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 22.3/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 22.5/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 22.6/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 22.8/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 22.9/44.0 MB 2.6 MB/s eta 0:00:09
#    -------------------- ------------------- 23.0/44.0 MB 2.6 MB/s eta 0:00:09
#    --------------------- ------------------ 23.1/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.2/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.4/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.4/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.5/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.7/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.8/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 23.9/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 24.0/44.0 MB 2.6 MB/s eta 0:00:08
#    --------------------- ------------------ 24.1/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 24.2/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 24.4/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 24.5/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 24.6/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 24.7/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 24.8/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 25.0/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 25.1/44.0 MB 2.6 MB/s eta 0:00:08
#    ---------------------- ----------------- 25.2/44.0 MB 2.6 MB/s eta 0:00:08
#    ----------------------- ---------------- 25.4/44.0 MB 2.6 MB/s eta 0:00:08
#    ----------------------- ---------------- 25.4/44.0 MB 2.6 MB/s eta 0:00:08
#    ----------------------- ---------------- 25.6/44.0 MB 2.6 MB/s eta 0:00:08
#    ----------------------- ---------------- 25.8/44.0 MB 2.6 MB/s eta 0:00:07
#    ----------------------- ---------------- 25.8/44.0 MB 2.6 MB/s eta 0:00:07
#    ----------------------- ---------------- 26.0/44.0 MB 2.6 MB/s eta 0:00:07
#    ----------------------- ---------------- 26.1/44.0 MB 2.6 MB/s eta 0:00:07
#    ----------------------- ---------------- 26.2/44.0 MB 2.6 MB/s eta 0:00:07
#    ----------------------- ---------------- 26.3/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 26.4/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 26.6/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 26.7/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 26.8/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 26.9/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 27.0/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 27.2/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 27.3/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------ --------------- 27.4/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 27.6/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 27.7/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 27.8/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 28.0/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 28.0/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 28.2/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 28.3/44.0 MB 2.6 MB/s eta 0:00:07
#    ------------------------- -------------- 28.4/44.0 MB 2.6 MB/s eta 0:00:06
#    ------------------------- -------------- 28.5/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 28.7/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 28.8/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 28.9/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 29.0/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 29.2/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 29.3/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 29.4/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 29.5/44.0 MB 2.6 MB/s eta 0:00:06
#    -------------------------- ------------- 29.7/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 29.8/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 29.9/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 30.0/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 30.2/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 30.3/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 30.4/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 30.6/44.0 MB 2.6 MB/s eta 0:00:06
#    --------------------------- ------------ 30.7/44.0 MB 2.6 MB/s eta 0:00:06
#    ---------------------------- ----------- 30.8/44.0 MB 2.6 MB/s eta 0:00:06
#    ---------------------------- ----------- 30.9/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.1/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.2/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.3/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.4/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.5/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.7/44.0 MB 2.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 31.8/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 31.9/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.1/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.2/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.3/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.4/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.6/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.7/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.7/44.0 MB 2.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 32.9/44.0 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 33.0/44.0 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 33.1/44.0 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 33.2/44.0 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 33.4/44.0 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 33.5/44.0 MB 2.6 MB/s eta 0:00:05
#    ------------------------------ --------- 33.6/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------ --------- 33.7/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------ --------- 33.8/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------ --------- 33.9/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------ --------- 34.0/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.1/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.2/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.4/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.5/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.6/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.7/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 34.9/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 35.0/44.0 MB 2.6 MB/s eta 0:00:04
#    ------------------------------- -------- 35.1/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 35.2/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 35.4/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 35.5/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 35.6/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 35.7/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 35.9/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 36.0/44.0 MB 2.6 MB/s eta 0:00:04
#    -------------------------------- ------- 36.1/44.0 MB 2.6 MB/s eta 0:00:03
#    -------------------------------- ------- 36.2/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 36.4/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 36.4/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 36.6/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 36.7/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 36.8/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 36.9/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 37.0/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 37.2/44.0 MB 2.6 MB/s eta 0:00:03
#    --------------------------------- ------ 37.3/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 37.4/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 37.5/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 37.6/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 37.7/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 37.8/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 38.0/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 38.1/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 38.2/44.0 MB 2.6 MB/s eta 0:00:03
#    ---------------------------------- ----- 38.4/44.0 MB 2.6 MB/s eta 0:00:03
#    ----------------------------------- ---- 38.5/44.0 MB 2.6 MB/s eta 0:00:03
#    ----------------------------------- ---- 38.6/44.0 MB 2.6 MB/s eta 0:00:03
#    ----------------------------------- ---- 38.7/44.0 MB 2.6 MB/s eta 0:00:03
#    ----------------------------------- ---- 38.9/44.0 MB 2.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.0/44.0 MB 2.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.1/44.0 MB 2.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.2/44.0 MB 2.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.3/44.0 MB 2.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.5/44.0 MB 2.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 39.5/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 39.6/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 39.8/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 39.9/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 40.0/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 40.2/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 40.3/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 40.4/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 40.5/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 40.6/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------- -- 40.7/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------- -- 40.9/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------- -- 40.9/44.0 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------- -- 41.0/44.0 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 41.2/44.0 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 41.2/44.0 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 41.3/44.0 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 41.4/44.0 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 41.5/44.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 41.7/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 41.8/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 41.9/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.0/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.1/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.2/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.3/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.4/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.5/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.6/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.7/44.0 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 42.8/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.0/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.1/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.2/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.3/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.4/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.5/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.7/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 44.0/44.0 MB 2.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.0 scipy-1.11.2 threadpoolctl-3.2.0

# %%
import torch
import pytorch_lightning as p
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

train_data=datasets.MNIST(root='data',
                          train=True,
                          transform=ToTensor(),
                          download=True)

test_data=datasets.MNIST(root='data',
                        train=False,
                        transform=ToTensor())

# %%
train_data
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
test_data
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
len(train_data)
# Out:
# 60000

# %%
print(train_data.data.size())
print(train_data.targets.size())
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([60000])

# %%
import matplotlib.pyplot as plt

plt.imshow(train_data.data[0],cmap='gray')
plt.title(train_data.targets[0])
plt.show()

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_data), size=(1,)).item()
    img, label = train_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
from sklearn.model_selection import train_test_split


train_indices, val_indices,_,_ = train_test_split(
    range(len(train_data)),
    train_data.targets,
    stratify=train_data.targets,
    test_size=0.2)

# %%
train_split=torch.utils.data.Subset(train_data,train_indices)
val_split=torch.utils.data.Subset(train_data,val_indices)

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor
from sklearn.model_selection import train_test_split
import pytorch_lightning as pl
import torch

class MNISTDataModule(pl.LightningDataModule):
    def __init__(self):
        super().__init__()
        self.batch_size = 32
        self.train_split=None
        self.val_split=None
        self.test_split=None

    def prepare_data(self):
        datasets.MNIST(root='data', train=True, transform=ToTensor(), download=True)
        datasets.MNIST(root='data', train=False, transform=ToTensor(), download=True)

    def setup(self, stage=None):
        if stage == 'fit':
            self.train_dataset = datasets.MNIST(root='data', train=True, transform=ToTensor(), download=False)
            self.test_dataset = datasets.MNIST(root='data', train=False, transform=ToTensor(), download=False)

            self.train_indices, self.val_indices, _, _ = train_test_split(
                range(len(self.train_dataset)),
                self.train_dataset.targets,
                stratify=self.train_dataset.targets,
                test_size=0.2
            )

            self.train_split = torch.utils.data.Subset(self.train_dataset, self.train_indices)
            self.val_split = torch.utils.data.Subset(self.train_dataset, self.val_indices)
            

    def train_dataloader(self):
        return torch.utils.data.DataLoader(self.train_split, batch_size=self.batch_size)

    def val_dataloader(self):
        return torch.utils.data.DataLoader(self.val_split, batch_size=self.batch_size)

    def test_dataloader(self:p.LightningDataModule):
        self.test_indices = range(len(self.test_dataset))
        self.test_split = torch.utils.data.Subset(self.test_dataset, self.test_indices)
        return torch.utils.data.DataLoader(self.test_split, batch_size=self.batch_size)

# %%
import torch.nn as nn
import torchmetrics

class CNN(p.LightningModule):
    def __init__(self):
        super(CNN,self).__init__()
        
        self.conv1= nn.Sequential(
            nn.Conv2d(
                in_channels=1,
                out_channels=16,
                kernel_size=5,              
                stride=1,                   
                padding=2
            ),
            nn.ReLU(),
            nn.MaxPool2d(2))
        
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
            
        self.fc1=nn.Linear(32*7*7,10)
        
        self.train_acc = torchmetrics.classification.Accuracy(task="multiclass", num_classes=10)
        self.valid_acc = torchmetrics.classification.Accuracy(task="multiclass", num_classes=10)
        self.test_acc  = torchmetrics.classification.Accuracy(task="multiclass", num_classes=10)
    def forward(self,x):
        x=self.conv1(x)
        x=self.conv2(x)
        
        x = x.view(x.size(0), -1)   
        
        out=self.fc1(x)
        
        return out
        
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(),lr=0.001)
    
    def training_step(self, batch, batch_idx):
        x,y=batch
        y_pred=self(x)
        loss=nn.CrossEntropyLoss()(y_pred,y)
        self.train_acc(y_pred, y)
        self.log('train_acc', self.train_acc, on_step=True, on_epoch=False)
        self.log("train_loss", loss)
        return loss
    
    def validation_step(self,batch,batch_idx):
        x,y=batch
        y_pred = self(x)
        loss = nn.CrossEntropyLoss()(y_pred, y)
        self.valid_acc(y_pred, y)
        self.log('val_acc', self.valid_acc, on_step=True, on_epoch=True)
        self.log("val_loss", loss)
        
    def test_step(self, batch, batch_idx):
        x, y = batch
        y_pred = self(x)
        loss = nn.CrossEntropyLoss()(y_pred, y)
        self.log("test_loss", loss)
        self.test_acc(y_pred, y)
        self.log('test_acc', self.test_acc)
        return loss

# %%
CNN()
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Linear(in_features=1568, out_features=10, bias=True)
#   (train_acc): MulticlassAccuracy()
#   (valid_acc): MulticlassAccuracy()
#   (test_acc): MulticlassAccuracy()
# )

# %%
class LoggingCallback(p.Callback):
    def on_train_epoch_end(self,trainer:p.Trainer,pl_module: p.LightningModule):
        epoch = trainer.current_epoch
        logs=trainer.callback_metrics

        loss = logs.get('train_loss')
        accuracy = logs.get('train_acc')

        
        print(f"Epoch {epoch} - Training Loss: {loss} - Accuracy: {accuracy}")
    
    def on_validation_epoch_end(self, trainer: p.Trainer, pl_module: p.LightningModule) -> None:
      
        epoch = trainer.current_epoch
        logs=trainer.callback_metrics

        accuracy=logs.get('val_acc')
        loss = logs.get('val_loss')

        print(f"Epoch {epoch} - V Loss: {loss} - Accuracy: {accuracy}")

# %%
from pytorch_lightning.callbacks import ModelCheckpoint,EarlyStopping

checkpoint_callback = ModelCheckpoint(
        monitor='val_acc', 
        save_top_k=1, 
        mode='max',
        dirpath='saved/',
        filename='sample-mnist-{epoch:02d}-{val_loss:.2f}')
    
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
datamodule = MNISTDataModule()
model = CNN()
trainer = p.Trainer(
        callbacks=[LoggingCallback(),checkpoint_callback,early_stopping_callback],
        max_epochs=2,
        
        profiler='simple'
    )
trainer.fit(model, datamodule=datamodule)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# C:\Users\ASUS\anaconda3\Lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:617: UserWarning: Checkpoint directory C:\Users\ASUS\Desktop\fsdl\saved exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type               | Params
# -------------------------------------------------
# 0 | conv1     | Sequential         | 416
# 1 | conv2     | Sequential         | 12.8 K
# 2 | fc1       | Linear             | 15.7 K
# 3 | train_acc | MulticlassAccuracy | 0
# 4 | valid_acc | MulticlassAccuracy | 0
# 5 | test_acc  | MulticlassAccuracy | 0
# -------------------------------------------------
# 28.9 K    Trainable params
# 0         Non-trainable params
# 28.9 K    Total params
# 0.116     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Epoch 0 - V Loss: 2.306661367416382 - Accuracy: 0.078125
# C:\Users\ASUS\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:438: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:438: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Epoch 0 - V Loss: 0.06242285296320915 - Accuracy: 0.981333315372467
# Epoch 0 - Training Loss: 0.1288505643606186 - Accuracy: 0.9375
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=2` reached.
# FIT Profiler Report
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                              	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                               	|  -              	|  157718         	|  63.204         	|  100 %          	|
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                  	|  31.344         	|  2              	|  62.688         	|  99.184         	|
# |  run_training_batch                                                                                                                                                  	|  0.0069967      	|  3000           	|  20.99          	|  33.21          	|
# |  [LightningModule]CNN.optimizer_step                                                                                                                                 	|  0.0069183      	|  3000           	|  20.755         	|  32.838         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                          	|  0.0063987      	|  3000           	|  19.196         	|  30.371         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                        	|  0.004481       	|  3000           	|  13.443         	|  21.269         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                      	|  0.0066237      	|  752            	|  4.981          	|  7.8808         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                        	|  0.0013607      	|  3000           	|  4.082          	|  6.4585         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                             	|  0.0012607      	|  3000           	|  3.782          	|  5.9838         	|
# |  [_EvaluationLoop].val_next                                                                                                                                          	|  0.004166       	|  753            	|  3.137          	|  4.9633         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                      	|  0.00027878     	|  3752           	|  1.046          	|  1.655          	|
# |  [LightningModule]CNN.transfer_batch_to_device                                                                                                                       	|  0.00020416     	|  3752           	|  0.766          	|  1.2119         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                   	|  0.00099202     	|  752            	|  0.746          	|  1.1803         	|
# |  [LightningModule]CNN.optimizer_zero_grad                                                                                                                            	|  0.00013333     	|  3000           	|  0.4            	|  0.63287        	|
# |  [LightningModule]CNN.configure_gradient_clipping                                                                                                                    	|  5.2333e-05     	|  3000           	|  0.157          	|  0.2484         	|
# |  [LightningDataModule]MNISTDataModule.prepare_data                                                                                                                   	|  0.125          	|  1              	|  0.125          	|  0.19777        	|
# |  [LightningDataModule]MNISTDataModule.setup                                                                                                                          	|  0.125          	|  1              	|  0.125          	|  0.19777        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  3.1333e-05     	|  3000           	|  0.094          	|  0.14872        	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                  	|  1.5667e-05     	|  3000           	|  0.047          	|  0.074362       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                                    	|  0.016          	|  2              	|  0.032          	|  0.05063        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                       	|  0.010333       	|  3              	|  0.031          	|  0.049048       	|
# |  [Callback]LoggingCallback.on_train_batch_end                                                                                                                        	|  1.0333e-05     	|  3000           	|  0.031          	|  0.049048       	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                           	|  1e-05          	|  3000           	|  0.03           	|  0.047465       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.015          	|  2              	|  0.03           	|  0.047465       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                             	|  2.1277e-05     	|  752            	|  0.016          	|  0.025315       	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                      	|  2.1277e-05     	|  752            	|  0.016          	|  0.025315       	|
# |  [Callback]LoggingCallback.on_validation_epoch_end                                                                                                                   	|  0.0053333      	|  3              	|  0.016          	|  0.025315       	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                         	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [LightningModule]CNN.on_train_batch_start                                                                                                                           	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]LoggingCallback.on_before_zero_grad                                                                                                                       	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                       	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]LoggingCallback.on_before_backward                                                                                                                        	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                           	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                              	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                                    	|  5.3333e-06     	|  3000           	|  0.016          	|  0.025315       	|
# |  [LightningModule]CNN.on_after_batch_transfer                                                                                                                        	|  3.9979e-06     	|  3752           	|  0.015          	|  0.023733       	|
# |  [Callback]LoggingCallback.on_after_backward                                                                                                                         	|  5e-06          	|  3000           	|  0.015          	|  0.023733       	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                     	|  0.015          	|  1              	|  0.015          	|  0.023733       	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                            	|  0.015          	|  1              	|  0.015          	|  0.023733       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                            	|  5e-06          	|  3000           	|  0.015          	|  0.023733       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                     	|  5e-06          	|  3000           	|  0.015          	|  0.023733       	|
# |  [LightningModule]CNN.configure_callbacks                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.prepare_data                                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.setup                                                                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.setup                                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.setup                                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.configure_sharded_model                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.configure_optimizers                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_fit_start                                                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_fit_start                                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_sanity_check_start                                                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningDataModule]MNISTDataModule.val_dataloader                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_model_eval                                                                                                                       	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_validation_start                                                                                                                       	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                                   	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                          	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_start                                                                                                                            	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                  	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_validation_epoch_start                                                                                                                 	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                             	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                 	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                    	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_epoch_start                                                                                                                      	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_before_batch_transfer                                                                                                                       	|  0.0            	|  3752           	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_validation_batch_start                                                                                                                 	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                 	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                    	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_batch_start                                                                                                                      	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_validation_batch_end                                                                                                                   	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                               	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_batch_end                                                                                                                        	|  0.0            	|  752            	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                               	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                   	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                      	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_epoch_end                                                                                                                        	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_validation_end                                                                                                                         	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                     	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                         	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                            	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_end                                                                                                                              	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                    	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_validation_model_train                                                                                                                      	|  0.0            	|  3              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_sanity_check_end                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningDataModule]MNISTDataModule.train_dataloader                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_train_start                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_train_start                                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_train_epoch_start                                                                                                                      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                         	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_train_epoch_start                                                                                                                           	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_train_batch_start                                                                                                                      	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                                  	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                      	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                 	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                                   	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                          	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_before_zero_grad                                                                                                                            	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                                    	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                        	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_before_backward                                                                                                                             	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                     	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                         	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_after_backward                                                                                                                              	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_before_optimizer_step                                                                                                                  	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_before_optimizer_step                                                                                                                       	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_train_batch_end                                                                                                                             	|  0.0            	|  3000           	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_train_epoch_end                                                                                                                        	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                        	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                           	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_train_epoch_end                                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningDataModule]MNISTDataModule.state_dict                                                                                                                     	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_save_checkpoint                                                                                                                        	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                        	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                           	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_save_checkpoint                                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_train_end                                                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_train_end                                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.on_fit_end                                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.on_fit_end                                                                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningDataModule]MNISTDataModule.teardown                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]LoggingCallback.teardown                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.teardown                                                                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_acc', 'mode': 'max', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]CNN.teardown                                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1 - V Loss: 0.05118288844823837 - Accuracy: 0.984000027179718
# Epoch 1 - Training Loss: 0.0689249336719513 - Accuracy: 0.96875

# %%
datamodule = MNISTDataModule()
from pytorch_lightning.profiler import SimpleProfiler

profiler = SimpleProfiler()

model = CNN()
trainer = p.Trainer(
        callbacks=[LoggingCallback(),checkpoint_callback,early_stopping_callback],
        max_epochs=2,
        
        profiler=profiler
    )
trainer.fit(model, datamodule=datamodule)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_13076\3900149105.py", line 2, in <module>
#     from pytorch_lightning.profiler import SimpleProfiler
# ModuleNotFoundError: No module named 'pytorch_lightning.profiler'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 677, in included_pieces
#     scope_pieces = self.scope_pieces
#                    ^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 614, in scope_pieces
#     scope_start, scope_end = self.source.line_range(self.scope)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 178, in line_range
#     return line_range(self.asttext(), node)
#                       ^^^^^^^^^^^^
# AttributeError: 'Source' object has no attribute 'asttext'

# %%
test_dataloader= datamodule.test_dataloader()

true=[]
pred=[]

for batch in test_dataloader:
    x,y=batch
    with torch.no_grad():
        y_pred=model(x)
        
    _,predicted = torch.max(y_pred, 1)
#     print(predicted)
    
    true.extend(y.tolist())
    pred.extend(predicted.tolist())
    break

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
#     sample_idx = torch.randint(len(train_data), size=(1,)).item()
    img=x[i]
    figure.add_subplot(rows, cols, i)
    plt.title(pred[i])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()
